# %%
import pandas as pd

# %%
df = pd.read_csv(r'Houses_for_sale_processed.csv')
df.head(5)
# Out:
#    property_id         lon        lat  postal_code       state      city  \
# 0   1000163193 -122.340542  37.948990        94804  California  Richmond
# 1   1000748625 -122.196956  47.918020        98208  Washington   Everett
# 2   1001237574 -112.313678  33.763826        85383     Arizona    Peoria
# 3   1001483948 -117.133291  33.540322        92591  California  Temecula
# 4   1001489359 -122.206693  37.804517        94602  California   Oakland
#
#   state_code                       line  fips_code          name  ... beds  \
# 0         CA            2814 Lowell Ave     6013.0  Contra Costa  ...  2.0
# 1         WA          8729 Del Campo Dr    53061.0     Snohomish  ...  4.0
# 2         AZ           31010 N 117th Dr     4013.0      Maricopa  ...  4.0
# 3         CA  39920 N General Kearny Rd     6065.0     Riverside  ...  4.0
# 4         CA            2520 Rampart St     6001.0       Alameda  ...  2.0
#
#             type                                      primary_photo  \
# ...

# %%
columns = ['state_code', 'line','postal_code', 'state','name']
df.drop(columns = columns, inplace=True)

# %%
df.head(5)
# Out:
#    property_id         lon        lat      city  fips_code  \
# 0   1000163193 -122.340542  37.948990  Richmond     6013.0
# 1   1000748625 -122.196956  47.918020   Everett    53061.0
# 2   1001237574 -112.313678  33.763826    Peoria     4013.0
# 3   1001483948 -117.133291  33.540322  Temecula     6065.0
# 4   1001489359 -122.206693  37.804517   Oakland     6001.0
#
#   is_new_construction is_plan is_price_reduced is_foreclosure is_coming_soon  \
# 0                 NaN     NaN              NaN            NaN            NaN
# 1                 NaN     NaN              NaN            NaN            NaN
# 2                 NaN     NaN              NaN            NaN            NaN
# 3                 NaN     NaN              NaN            NaN            NaN
# 4                 NaN     NaN              NaN            NaN            NaN
#
#    ... beds           type                                      primary_photo  \
# ...
